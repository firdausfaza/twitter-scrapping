# %%
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
import csv
from google_play_scraper import app, reviews_all, Sort, reviews
import numpy as np
import pandas as pd
from time import sleep

# %%
# com.tokopedia.tkpd
result, continuation_token = reviews(
    'com.tokopedia.tkpd',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=200, # defaults to 100
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId                      userName  \
# 0  1bb08fef-ec09-4637-bcd1-3343f02682e7                   Yumnan Dani
# 1  2a703bd1-515b-4984-aedb-56df31ceac6d  SABDA TV DIGIPRENEURLABPEDIA
# 2  152a68f7-fcd9-425b-b705-bc8127a3a197              Rachmad Ramadhan
# 3  48978126-0a44-415c-acce-8de7eebd3004                   Sukri Sukri
# 4  b204768e-269f-435d-b8af-2a9a0e5f20bf          Putri Ayu Widiastuti
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                              content  score  thumbsUpCount  \
# 0  Paraah banget csnyaa! Responnya lamaa banget b...      1              0
# 1                           karya anak bangsa mantap      5              0
# 2  Tolong dibuatkan kolom penilaian kurir karena ...      2              0
# 3  kalau aku belanja online COD saya pakai aplika...      5              0
# 4                                               🇦🇺🇦🇺      1              0
#
#   reviewCreatedVersion                  at  \
# 0                3.219 2023-06-03 12:56:12
# 1                 None 2023-06-03 12:55:42
# 2                 None 2023-06-03 12:45:14
# 3                 None 2023-06-03 12:44:48
# 4                 None 2023-06-03 12:27:09
#
#                                         replyContent           repliedAt  \
# 0  Halo Toppers, terima kasih atas rating yang ka... 2023-06-03 13:25:01
# 1  Hi Toppers, terima kasih untuk rating dan ulas... 2023-06-03 13:25:02
# 2  Halo Toppers, terima kasih atas rating yang ka... 2023-06-03 13:05:03
# 3  Terima kasih sudah mempercayakan Tokopedia seb... 2023-06-03 13:05:04
# 4                                               None                 NaT
#
#   appVersion
# 0      3.219
# 1       None
# 2       None
# 3       None
# 4       None
